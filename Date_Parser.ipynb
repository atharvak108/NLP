# %%
import csv
from datetime import datetime
import re
import pandas as pd
import numpy as np

# %%
# Function to load CSV file using DictReader
def load_csv(filepath):
    with open(filepath, mode='r') as file:
        csv_reader = csv.DictReader(file)
        extracted_data = [(row['Input'], row['Expected Output']) for row in csv_reader]
    return extracted_data

# Function to identify and format dates from text
def extract_date(text):
    # Define different regex patterns for date formats
    regex_patterns = [
        r'(\d{1,2})(st|nd|rd|th)?\s+of\s+(January|February|March|April|May|June|July|August|September|October|November|December)\s+(\d{4})',
        r'(\d{1,2})(st|nd|rd|th)?\s+(January|February|March|April|May|June|July|August|September|October|November|December),?\s+(\d{4})',
        r'(\d{1,2})(st|nd|rd|th)?\s+(Jan|Feb|Mar|Apr|May|Jun|Jul|Aug|Sep|Oct|Nov|Dec),?\s+(\d{4})',
        r'(\d{4})-(\d{2})-(\d{2})',
        r'(\d{1,2})/(\d{1,2})/(\d{4})'
    ]
    
    month_map = {
        'January': '01', 'February': '02', 'March': '03', 'April': '04', 'May': '05', 'June': '06',
        'July': '07', 'August': '08', 'September': '09', 'October': '10', 'November': '11', 'December': '12',
        'Jan': '01', 'Feb': '02', 'Mar': '03', 'Apr': '04', 'May': '05', 'Jun': '06',
        'Jul': '07', 'Aug': '08', 'Sep': '09', 'Oct': '10', 'Nov': '11', 'Dec': '12'
    }

    # Iterate through regex patterns and check for matches
    for regex in regex_patterns:
        matched = re.search(regex, text)
        if matched:
            # If match includes a full month name
            if len(matched.groups()) == 4:
                day, _, month, year = matched.groups()
                day = day.zfill(2)
                month = month_map[month]
                return f"{day}/{month}/{year}"
            # If match includes a year-month-day format
            elif len(matched.groups()) == 3:
                year, month, day = matched.groups()
                return f"{day}/{month}/{year}"
            # If match includes a day, month, and year in numeric format
            elif len(matched.groups()) == 3:
                day, month, year = matched.groups()
                day = day.zfill(2)
                month = month.zfill(2)
                return f"{day}/{month}/{year}"
    return None

# Load test cases from a CSV file
csv_filepath = 'date_parser_testcases.csv'
test_data = load_csv(csv_filepath)

# Print the data read from the CSV for verification
print("Loaded test cases:")
for input_text, expected in test_data:
    print(f"Input: {input_text}, Expected: {expected}")

# Evaluate the date extraction function
for input_text, expected_output in test_data:
    extracted_date = extract_date(input_text)
    print(f"Input Text: {input_text}")
    print(f"Extracted Date: {extracted_date}")
    print(f"Expected Output: {expected_output}")
    print(f"Does it match? {extracted_date == expected_output}\n")
# Out:
# Loaded test cases:
# Input: The event will take place on March 5, 2023., Expected: 05/03/2023
# Input: Her birthday is on 07/08/1990., Expected: 07/08/1990
# Input: The deadline is 2022-12-31., Expected: 31/12/2022
# Input: We met on 1st of January 2000., Expected: 01/01/2000
# Input: The concert is scheduled for 15th September, 2021., Expected: 15/09/2021
# Input: Let's catch up on 02.04.2022., Expected: 02/04/2022
# Input: The project started on 5/6/19., Expected: 05/06/2019
# Input: He was born on 1987/11/23., Expected: 23/11/1987
# Input: Christmas is on 25th Dec 2024., Expected: 25/12/2024
# Input: The meeting is set for April 03, 2020., Expected: 03/04/2020
# Input: Her birthdate, noted as 1997-05-20, is in the records., Expected: 20/05/1997
# Input: Her appointment is on the 2nd of March, 2021., Expected: 02/03/2021
# Input: The exam date is 2021.11.10., Expected: 10/11/2021
# Input: They got married on 12/12/12., Expected: 12/12/2012
# Input: The workshop is on February 15th, 2022., Expected: 15/02/2022
# Input: Submit your report by 08/31/2021., Expected: 31/08/2021
# Input: The course starts on 1st July 2023., Expected: 01/07/2023
# Input: Independence Day is on 4th of July, 2022., Expected: 04/07/2022
# Input: His birthday is 1995/10/30., Expected: 30/10/1995
# Input: The new year begins on 01-01-2023., Expected: 01/01/2023
# Input: The seminar is on 03/14/2022., Expected: 14/03/2022
# Input: My last day is 31.08.2020., Expected: 31/08/2020
# Input: The due date is 2020-02-28., Expected: 28/02/2020
# Input: The holiday starts on Dec 20th, 2021., Expected: 20/12/2021
# Input: The conference will be held on 5th May 2023., Expected: 05/05/2023
# Input: They moved in on 12/25/2019., Expected: 25/12/2019
# Input: The festival begins on March 17, 2022., Expected: 17/03/2022
# Input: The ceremony is on 11.11.2021., Expected: 11/11/2021
# Input: The event is on 2023/07/04., Expected: 04/07/2023
# Input: Her graduation is on May 30th, 2022., Expected: 30/05/2022
# Input: The release date is 2021-09-09., Expected: 09/09/2021
# Input: The interview is on 1/2/2022., Expected: 01/02/2022
# Input: The celebration is on 2022-10-10., Expected: 10/10/2022
# Input: His wedding is on 6th of August, 2020., Expected: 06/08/2020
# Input: She was born on 3rd March 1998., Expected: 03/03/1998
# Input: The opening is on 10/10/2018., Expected: 10/10/2018
# Input: The deadline is 2020.12.15., Expected: 15/12/2020
# Input: The party is on 31-12-2022., Expected: 31/12/2022
# Input: The workshop is on February 29, 2024., Expected: 29/02/2024
# Input: Vacation starts on 07/15/2021., Expected: 15/07/2021
# Input: The application is due by 2022-03-03., Expected: 03/03/2022
# Input: The tournament is on June 1st, 2021., Expected: 01/06/2021
# Input: The closing date is 08/08/2020., Expected: 08/08/2020
# Input: The concert is on 2020/09/09., Expected: 09/09/2020
# Input: The exam is on 01.01.2022., Expected: 01/01/2022
# Input: Independence Day is 2023-07-04., Expected: 04/07/2023
# Input: The last date is 30th November 2022., Expected: 30/11/2022
# Input: The conference is on 15th October 2023., Expected: 15/10/2023
# Input: His birthdate is 1990-05-20., Expected: 20/05/1990
# Input: The festival is on 12th August 2024., Expected: 12/08/2024
# Input: Input, Expected: Expected Output
# Input: We are planning to meet on March 5, 2023, for lunch., Expected: 05/03/2023
# Input: Her birthday, which she celebrates on 07/08/1990, is coming up soon., Expected: 07/08/1990
# Input: The deadline, unfortunately, is set to 2022-12-31., Expected: 31/12/2022
# Input: We first met on the 1st of January 2000 at the conference., Expected: 01/01/2000
# Input: The concert, happening on 15th September 2021, will be amazing., Expected: 15/09/2021
# Input: Remember, the meeting is on 02.04.2022 at 10 AM., Expected: 02/04/2022
# Input: Let's wrap up the project by 5/6/19, so we can relax., Expected: 05/06/2019
# Input: His birth date, recorded as 1987/11/23, was a memorable day., Expected: 23/11/1987
# Input: We celebrate Christmas every year on 25th Dec, including 2024., Expected: 25/12/2024
# Input: The meeting is rescheduled to April 03, 2020, as per the latest update., Expected: 03/04/2020
# Input: Their anniversary is marked on the 2nd of March, 2021., Expected: 02/03/2021
# Input: The official exam date is now 2021.11.10, per the new schedule., Expected: 10/11/2021
# Input: They celebrated their wedding on 12/12/12 in grand style., Expected: 12/12/2012
# Input: Our next workshop is scheduled for February 15th, 2022., Expected: 15/02/2022
# Input: The submission deadline, noted as 08/31/2021, is fast approaching., Expected: 31/08/2021
# Input: The course officially begins on 1st July 2023., Expected: 01/07/2023
# Input: We celebrate Independence Day on the 4th of July every year, including 2022., Expected: 04/07/2022
# Input: He mentioned that his birth date is 1995/10/30 in the form., Expected: 30/10/1995
# Input: The new year's celebration begins on 01-01-2023 at midnight., Expected: 01/01/2023
# Input: We scheduled the seminar for 03/14/2022, don't forget., Expected: 14/03/2022
# Input: My final working day here is noted as 31.08.2020., Expected: 31/08/2020
# Input: The project's due date is officially 2020-02-28., Expected: 28/02/2020
# Input: The holiday vacation starts on Dec 20th, 2021, for everyone., Expected: 20/12/2021
# Input: The conference, marked for 5th May 2023, is a significant event., Expected: 05/05/2023
# Input: They officially moved in on 12/25/2019., Expected: 25/12/2019
# Input: Our festival starts on March 17, 2022, with a parade., Expected: 17/03/2022
# Input: The ceremony date is fixed as 11.11.2021., Expected: 11/11/2021
# Input: The big event is planned for 2023/07/04, so mark your calendars., Expected: 04/07/2023
# Input: Her graduation day is set for May 30th, 2022., Expected: 30/05/2022
# Input: The software release date is set for 2021-09-09., Expected: 09/09/2021
# Input: The job interview is on 1/2/2022, don't be late., Expected: 01/02/2022
# Input: The grand celebration is on 2022-10-10, a date to remember., Expected: 10/10/2022
# Input: The wedding is on 6th of August, 2020, in the evening., Expected: 06/08/2020
# Input: She mentioned she was born on the 3rd of March 1998., Expected: 03/03/1998
# Input: The official opening date is 10/10/2018, as per the announcement., Expected: 10/10/2018
# Input: The critical deadline is 2020.12.15, please note it., Expected: 15/12/2020
# Input: The New Year's Eve party is on 31-12-2022, join us!, Expected: 31/12/2022
# Input: The next workshop is on February 29, 2024, due to the leap year., Expected: 29/02/2024
# Input: Vacation officially starts on 07/15/2021, get ready., Expected: 15/07/2021
# Input: The application submission date is 2022-03-03., Expected: 03/03/2022
# Input: The tournament begins on June 1st, 2021, early in the morning., Expected: 01/06/2021
# Input: The registration closing date is 08/08/2020., Expected: 08/08/2020
# Input: The music concert is scheduled for 2020/09/09., Expected: 09/09/2020
# Input: The exam will be held on 01.01.2022, start preparing., Expected: 01/01/2022
# Input: We celebrate Independence Day on 2023-07-04, as always., Expected: 04/07/2023
# Input: The final date for submission is 30th November 2022., Expected: 30/11/2022
# Input: The annual conference is on 15th October 2023, mark your calendars., Expected: 15/10/2023
# Input: His birthdate, noted as 1990-05-20, is in the records., Expected: 20/05/1990
# Input: The festival will be celebrated on 12th August 2024, with grand events., Expected: 12/08/2024
# Input Text: The event will take place on March 5, 2023.
# Extracted Date: None
# Expected Output: 05/03/2023
# Does it match? False
#
# Input Text: Her birthday is on 07/08/1990.
# Extracted Date: 1990/08/07
# Expected Output: 07/08/1990
# Does it match? False
#
# Input Text: The deadline is 2022-12-31.
# Extracted Date: 31/12/2022
# Expected Output: 31/12/2022
# Does it match? True
#
# Input Text: We met on 1st of January 2000.
# Extracted Date: 01/01/2000
# Expected Output: 01/01/2000
# Does it match? True
#
# Input Text: The concert is scheduled for 15th September, 2021.
# Extracted Date: 15/09/2021
# Expected Output: 15/09/2021
# Does it match? True
#
# Input Text: Let's catch up on 02.04.2022.
# Extracted Date: None
# Expected Output: 02/04/2022
# Does it match? False
#
# Input Text: The project started on 5/6/19.
# Extracted Date: None
# Expected Output: 05/06/2019
# Does it match? False
#
# Input Text: He was born on 1987/11/23.
# Extracted Date: None
# Expected Output: 23/11/1987
# Does it match? False
#
# Input Text: Christmas is on 25th Dec 2024.
# Extracted Date: 25/12/2024
# Expected Output: 25/12/2024
# Does it match? True
#
# Input Text: The meeting is set for April 03, 2020.
# Extracted Date: None
# Expected Output: 03/04/2020
# Does it match? False
#
# Input Text: Her birthdate, noted as 1997-05-20, is in the records.
# Extracted Date: 20/05/1997
# Expected Output: 20/05/1997
# Does it match? True
#
# Input Text: Her appointment is on the 2nd of March, 2021.
# Extracted Date: None
# Expected Output: 02/03/2021
# Does it match? False
#
# Input Text: The exam date is 2021.11.10.
# Extracted Date: None
# Expected Output: 10/11/2021
# Does it match? False
#
# Input Text: They got married on 12/12/12.
# Extracted Date: None
# Expected Output: 12/12/2012
# Does it match? False
#
# Input Text: The workshop is on February 15th, 2022.
# Extracted Date: None
# Expected Output: 15/02/2022
# Does it match? False
#
# Input Text: Submit your report by 08/31/2021.
# Extracted Date: 2021/31/08
# Expected Output: 31/08/2021
# Does it match? False
#
# Input Text: The course starts on 1st July 2023.
# Extracted Date: 01/07/2023
# Expected Output: 01/07/2023
# Does it match? True
#
# Input Text: Independence Day is on 4th of July, 2022.
# Extracted Date: None
# Expected Output: 04/07/2022
# Does it match? False
#
# Input Text: His birthday is 1995/10/30.
# Extracted Date: None
# Expected Output: 30/10/1995
# Does it match? False
#
# Input Text: The new year begins on 01-01-2023.
# Extracted Date: None
# Expected Output: 01/01/2023
# Does it match? False
#
# Input Text: The seminar is on 03/14/2022.
# Extracted Date: 2022/14/03
# Expected Output: 14/03/2022
# Does it match? False
#
# Input Text: My last day is 31.08.2020.
# Extracted Date: None
# Expected Output: 31/08/2020
# Does it match? False
#
# Input Text: The due date is 2020-02-28.
# Extracted Date: 28/02/2020
# Expected Output: 28/02/2020
# Does it match? True
#
# Input Text: The holiday starts on Dec 20th, 2021.
# Extracted Date: None
# Expected Output: 20/12/2021
# Does it match? False
#
# Input Text: The conference will be held on 5th May 2023.
# Extracted Date: 05/05/2023
# Expected Output: 05/05/2023
# Does it match? True
#
# Input Text: They moved in on 12/25/2019.
# Extracted Date: 2019/25/12
# Expected Output: 25/12/2019
# Does it match? False
#
# Input Text: The festival begins on March 17, 2022.
# Extracted Date: None
# Expected Output: 17/03/2022
# Does it match? False
#
# Input Text: The ceremony is on 11.11.2021.
# Extracted Date: None
# Expected Output: 11/11/2021
# Does it match? False
#
# Input Text: The event is on 2023/07/04.
# Extracted Date: None
# Expected Output: 04/07/2023
# Does it match? False
#
# Input Text: Her graduation is on May 30th, 2022.
# Extracted Date: None
# Expected Output: 30/05/2022
# Does it match? False
#
# Input Text: The release date is 2021-09-09.
# Extracted Date: 09/09/2021
# Expected Output: 09/09/2021
# Does it match? True
#
# Input Text: The interview is on 1/2/2022.
# Extracted Date: 2022/2/1
# Expected Output: 01/02/2022
# Does it match? False
#
# Input Text: The celebration is on 2022-10-10.
# Extracted Date: 10/10/2022
# Expected Output: 10/10/2022
# Does it match? True
#
# Input Text: His wedding is on 6th of August, 2020.
# Extracted Date: None
# Expected Output: 06/08/2020
# Does it match? False
#
# Input Text: She was born on 3rd March 1998.
# Extracted Date: 03/03/1998
# Expected Output: 03/03/1998
# Does it match? True
#
# Input Text: The opening is on 10/10/2018.
# Extracted Date: 2018/10/10
# Expected Output: 10/10/2018
# Does it match? False
#
# Input Text: The deadline is 2020.12.15.
# Extracted Date: None
# Expected Output: 15/12/2020
# Does it match? False
#
# Input Text: The party is on 31-12-2022.
# Extracted Date: None
# Expected Output: 31/12/2022
# Does it match? False
#
# Input Text: The workshop is on February 29, 2024.
# Extracted Date: None
# Expected Output: 29/02/2024
# Does it match? False
#
# Input Text: Vacation starts on 07/15/2021.
# Extracted Date: 2021/15/07
# Expected Output: 15/07/2021
# Does it match? False
#
# Input Text: The application is due by 2022-03-03.
# Extracted Date: 03/03/2022
# Expected Output: 03/03/2022
# Does it match? True
#
# Input Text: The tournament is on June 1st, 2021.
# Extracted Date: None
# Expected Output: 01/06/2021
# Does it match? False
#
# Input Text: The closing date is 08/08/2020.
# Extracted Date: 2020/08/08
# Expected Output: 08/08/2020
# Does it match? False
#
# Input Text: The concert is on 2020/09/09.
# Extracted Date: None
# Expected Output: 09/09/2020
# Does it match? False
#
# Input Text: The exam is on 01.01.2022.
# Extracted Date: None
# Expected Output: 01/01/2022
# Does it match? False
#
# Input Text: Independence Day is 2023-07-04.
# Extracted Date: 04/07/2023
# Expected Output: 04/07/2023
# Does it match? True
#
# Input Text: The last date is 30th November 2022.
# Extracted Date: 30/11/2022
# Expected Output: 30/11/2022
# Does it match? True
#
# Input Text: The conference is on 15th October 2023.
# Extracted Date: 15/10/2023
# Expected Output: 15/10/2023
# Does it match? True
#
# Input Text: His birthdate is 1990-05-20.
# Extracted Date: 20/05/1990
# Expected Output: 20/05/1990
# Does it match? True
#
# Input Text: The festival is on 12th August 2024.
# Extracted Date: 12/08/2024
# Expected Output: 12/08/2024
# Does it match? True
#
# Input Text: Input
# Extracted Date: None
# Expected Output: Expected Output
# Does it match? False
#
# Input Text: We are planning to meet on March 5, 2023, for lunch.
# Extracted Date: None
# Expected Output: 05/03/2023
# Does it match? False
#
# Input Text: Her birthday, which she celebrates on 07/08/1990, is coming up soon.
# Extracted Date: 1990/08/07
# Expected Output: 07/08/1990
# Does it match? False
#
# Input Text: The deadline, unfortunately, is set to 2022-12-31.
# Extracted Date: 31/12/2022
# Expected Output: 31/12/2022
# Does it match? True
#
# Input Text: We first met on the 1st of January 2000 at the conference.
# Extracted Date: 01/01/2000
# Expected Output: 01/01/2000
# Does it match? True
#
# Input Text: The concert, happening on 15th September 2021, will be amazing.
# Extracted Date: 15/09/2021
# Expected Output: 15/09/2021
# Does it match? True
#
# Input Text: Remember, the meeting is on 02.04.2022 at 10 AM.
# Extracted Date: None
# Expected Output: 02/04/2022
# Does it match? False
#
# Input Text: Let's wrap up the project by 5/6/19, so we can relax.
# Extracted Date: None
# Expected Output: 05/06/2019
# Does it match? False
#
# Input Text: His birth date, recorded as 1987/11/23, was a memorable day.
# Extracted Date: None
# Expected Output: 23/11/1987
# Does it match? False
#
# Input Text: We celebrate Christmas every year on 25th Dec, including 2024.
# Extracted Date: None
# Expected Output: 25/12/2024
# Does it match? False
#
# Input Text: The meeting is rescheduled to April 03, 2020, as per the latest update.
# Extracted Date: None
# Expected Output: 03/04/2020
# Does it match? False
#
# Input Text: Their anniversary is marked on the 2nd of March, 2021.
# Extracted Date: None
# Expected Output: 02/03/2021
# Does it match? False
#
# Input Text: The official exam date is now 2021.11.10, per the new schedule.
# Extracted Date: None
# Expected Output: 10/11/2021
# Does it match? False
#
# Input Text: They celebrated their wedding on 12/12/12 in grand style.
# Extracted Date: None
# Expected Output: 12/12/2012
# Does it match? False
#
# Input Text: Our next workshop is scheduled for February 15th, 2022.
# Extracted Date: None
# Expected Output: 15/02/2022
# Does it match? False
#
# Input Text: The submission deadline, noted as 08/31/2021, is fast approaching.
# Extracted Date: 2021/31/08
# Expected Output: 31/08/2021
# Does it match? False
#
# Input Text: The course officially begins on 1st July 2023.
# Extracted Date: 01/07/2023
# Expected Output: 01/07/2023
# Does it match? True
#
# Input Text: We celebrate Independence Day on the 4th of July every year, including 2022.
# Extracted Date: None
# Expected Output: 04/07/2022
# Does it match? False
#
# Input Text: He mentioned that his birth date is 1995/10/30 in the form.
# Extracted Date: None
# Expected Output: 30/10/1995
# Does it match? False
#
# Input Text: The new year's celebration begins on 01-01-2023 at midnight.
# Extracted Date: None
# Expected Output: 01/01/2023
# Does it match? False
#
# Input Text: We scheduled the seminar for 03/14/2022, don't forget.
# Extracted Date: 2022/14/03
# Expected Output: 14/03/2022
# Does it match? False
#
# Input Text: My final working day here is noted as 31.08.2020.
# Extracted Date: None
# Expected Output: 31/08/2020
# Does it match? False
#
# Input Text: The project's due date is officially 2020-02-28.
# Extracted Date: 28/02/2020
# Expected Output: 28/02/2020
# Does it match? True
#
# Input Text: The holiday vacation starts on Dec 20th, 2021, for everyone.
# Extracted Date: None
# Expected Output: 20/12/2021
# Does it match? False
#
# Input Text: The conference, marked for 5th May 2023, is a significant event.
# Extracted Date: 05/05/2023
# Expected Output: 05/05/2023
# Does it match? True
#
# Input Text: They officially moved in on 12/25/2019.
# Extracted Date: 2019/25/12
# Expected Output: 25/12/2019
# Does it match? False
#
# Input Text: Our festival starts on March 17, 2022, with a parade.
# Extracted Date: None
# Expected Output: 17/03/2022
# Does it match? False
#
# Input Text: The ceremony date is fixed as 11.11.2021.
# Extracted Date: None
# Expected Output: 11/11/2021
# Does it match? False
#
# Input Text: The big event is planned for 2023/07/04, so mark your calendars.
# Extracted Date: None
# Expected Output: 04/07/2023
# Does it match? False
#
# Input Text: Her graduation day is set for May 30th, 2022.
# Extracted Date: None
# Expected Output: 30/05/2022
# Does it match? False
#
# Input Text: The software release date is set for 2021-09-09.
# Extracted Date: 09/09/2021
# Expected Output: 09/09/2021
# Does it match? True
#
# Input Text: The job interview is on 1/2/2022, don't be late.
# Extracted Date: 2022/2/1
# Expected Output: 01/02/2022
# Does it match? False
#
# Input Text: The grand celebration is on 2022-10-10, a date to remember.
# Extracted Date: 10/10/2022
# Expected Output: 10/10/2022
# Does it match? True
#
# Input Text: The wedding is on 6th of August, 2020, in the evening.
# Extracted Date: None
# Expected Output: 06/08/2020
# Does it match? False
#
# Input Text: She mentioned she was born on the 3rd of March 1998.
# Extracted Date: 03/03/1998
# Expected Output: 03/03/1998
# Does it match? True
#
# Input Text: The official opening date is 10/10/2018, as per the announcement.
# Extracted Date: 2018/10/10
# Expected Output: 10/10/2018
# Does it match? False
#
# Input Text: The critical deadline is 2020.12.15, please note it.
# Extracted Date: None
# Expected Output: 15/12/2020
# Does it match? False
#
# Input Text: The New Year's Eve party is on 31-12-2022, join us!
# Extracted Date: None
# Expected Output: 31/12/2022
# Does it match? False
#
# Input Text: The next workshop is on February 29, 2024, due to the leap year.
# Extracted Date: None
# Expected Output: 29/02/2024
# Does it match? False
#
# Input Text: Vacation officially starts on 07/15/2021, get ready.
# Extracted Date: 2021/15/07
# Expected Output: 15/07/2021
# Does it match? False
#
# Input Text: The application submission date is 2022-03-03.
# Extracted Date: 03/03/2022
# Expected Output: 03/03/2022
# Does it match? True
#
# Input Text: The tournament begins on June 1st, 2021, early in the morning.
# Extracted Date: None
# Expected Output: 01/06/2021
# Does it match? False
#
# Input Text: The registration closing date is 08/08/2020.
# Extracted Date: 2020/08/08
# Expected Output: 08/08/2020
# Does it match? False
#
# Input Text: The music concert is scheduled for 2020/09/09.
# Extracted Date: None
# Expected Output: 09/09/2020
# Does it match? False
#
# Input Text: The exam will be held on 01.01.2022, start preparing.
# Extracted Date: None
# Expected Output: 01/01/2022
# Does it match? False
#
# Input Text: We celebrate Independence Day on 2023-07-04, as always.
# Extracted Date: 04/07/2023
# Expected Output: 04/07/2023
# Does it match? True
#
# Input Text: The final date for submission is 30th November 2022.
# Extracted Date: 30/11/2022
# Expected Output: 30/11/2022
# Does it match? True
#
# Input Text: The annual conference is on 15th October 2023, mark your calendars.
# Extracted Date: 15/10/2023
# Expected Output: 15/10/2023
# Does it match? True
#
# Input Text: His birthdate, noted as 1990-05-20, is in the records.
# Extracted Date: 20/05/1990
# Expected Output: 20/05/1990
# Does it match? True
#
# Input Text: The festival will be celebrated on 12th August 2024, with grand events.
# Extracted Date: 12/08/2024
# Expected Output: 12/08/2024
# Does it match? True
